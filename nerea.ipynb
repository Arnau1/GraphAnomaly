# %% [markdown]
# Label 1 -> illicit
# Label 2 -> licit

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import scipy as sp

import community as louvain
from networkx.algorithms.community import girvan_newman

# %%
classes = pd.read_csv('elliptic_bitcoin_dataset/elliptic_txs_classes.csv')
edges = pd.read_csv('elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv')
features = pd.read_csv('elliptic_bitcoin_dataset/elliptic_txs_features.csv')

# %%
classes.head()
# Out:
#         txId    class
# 0  230425980  unknown
# 1    5530458  unknown
# 2  232022460  unknown
# 3  232438397        2
# 4  230460314  unknown

# %%
edges.head()
# Out:
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %%
features.head()
# Out:
#    230425980  1  -0.1714692896288031  -0.18466755143291433  \
# 0    5530458  1            -0.171484             -0.184668
# 1  232022460  1            -0.172107             -0.184668
# 2  232438397  1             0.163054              1.963790
# 3  230460314  1             1.011523             -0.081127
# 4  230459870  1             0.961040             -0.081127
#
#    -1.2013688016765636  -0.12196959975910057  -0.04387454791734898  \
# 0            -1.201369             -0.121970             -0.043875
# 1            -1.201369             -0.121970             -0.043875
# 2            -0.646376             12.409294             -0.063725
# 3            -1.201369              1.153668              0.333276
# 4            -1.201369              1.303743              0.333276
#
#    -0.11300200928476244  -0.06158379407303222  -0.16209679981659642  ...  \
# 0             -0.113002             -0.061584             -0.162112  ...
# 1             -0.113002             -0.061584             -0.162749  ...
# 2              9.782742             12.414558             -0.163645  ...
# 3              1.312656             -0.061584             -0.163523  ...
# 4              1.480381             -0.061584             -0.163577  ...
#
#    -0.5621534802884299  -0.6009988905192808  1.4613303209554889  \
# 0             0.947382             0.673103           -0.979074
# 1             0.670883             0.439728           -0.979074
# 2            -0.577099            -0.613614            0.241128
# 3            -0.511871            -0.400422            0.517257
# 4            -0.504702            -0.422589           -0.226790
#
#    1.4613689382001922  0.01827940003744589  -0.0874901561101501  \
# 0           -0.978556             0.018279            -0.087490
# 1           -0.978556            -0.098889            -0.106715
# 2            0.241406             1.072793             0.085530
# 3            0.579382             0.018279             0.277775
# 4           -0.117629             0.018279             0.277775
#
#    -0.13115530389558736  -0.09752359377152515  -0.12061340670311574  \
# 0             -0.131155             -0.097524             -0.120613
# 1             -0.131155             -0.183671             -0.120613
# 2             -0.131155              0.677799             -0.120613
# 3              0.326394              1.293750              0.178136
# 4              0.413931              1.149556             -0.696053
#
#    -0.11979245961251665
# 0             -0.119792
# 1             -0.119792
# 2             -0.119792
# 3              0.179117
# 4             -0.695540
#
# [5 rows x 167 columns]

# %%
# Change column names of df_features
colNames1 = {'0': 'txId', 1: "Time step"}
colNames2 = {str(ii+2): "Local_feature_" + str(ii+1) for ii in range(93)}
colNames3 = {str(ii+95): "Aggregate_feature_" + str(ii+1) for ii in range(72)}

colNames = dict(colNames1, **colNames2, **colNames3 )
colNames = {int(jj): item_kk for jj,item_kk in colNames.items()}

features = features.rename(columns=colNames)
features
# Out:
#         230425980   1  -0.1714692896288031  -0.18466755143291433  \
# 0         5530458   1            -0.171484             -0.184668
# 1       232022460   1            -0.172107             -0.184668
# 2       232438397   1             0.163054              1.963790
# 3       230460314   1             1.011523             -0.081127
# 4       230459870   1             0.961040             -0.081127
# ...           ...  ..                  ...                   ...
# 203763  173077460  49            -0.145771             -0.163752
# 203764  158577750  49            -0.165920             -0.123607
# 203765  158375402  49            -0.172014             -0.078182
# 203766  158654197  49            -0.172842             -0.176622
# 203767  157597225  49            -0.012037             -0.132276
#
#         -1.2013688016765636  -0.12196959975910057  -0.04387454791734898  \
# 0                 -1.201369             -0.121970             -0.043875
# 1                 -1.201369             -0.121970             -0.043875
# 2                 -0.646376             12.409294             -0.063725
# 3                 -1.201369              1.153668              0.333276
# 4                 -1.201369              1.303743              0.333276
# ...                     ...                   ...                   ...
# 203763             0.463609             -0.121970             -0.043875
# 203764             1.018602             -0.121970             -0.043875
# 203765             1.018602              0.028105             -0.043875
# 203766             1.018602             -0.121970             -0.043875
# 203767             0.463609             -0.121970             -0.043875
#
#         -0.11300200928476244  -0.06158379407303222  -0.16209679981659642  ...  \
# 0                  -0.113002             -0.061584             -0.162112  ...
# 1                  -0.113002             -0.061584             -0.162749  ...
# 2                   9.782742             12.414558             -0.163645  ...
# 3                   1.312656             -0.061584             -0.163523  ...
# 4                   1.480381             -0.061584             -0.163577  ...
# ...                      ...                   ...                   ...  ...
# 203763             -0.113002             -0.061584             -0.135803  ...
# 203764             -0.113002             -0.061584             -0.156418  ...
# 203765              0.054722             -0.061584             -0.163626  ...
# 203766             -0.113002             -0.061584             -0.163501  ...
# 203767             -0.113002             -0.061584              0.001027  ...
#
#         -0.5621534802884299  -0.6009988905192808  1.4613303209554889  \
# 0                  0.947382             0.673103           -0.979074
# 1                  0.670883             0.439728           -0.979074
# 2                 -0.577099            -0.613614            0.241128
# 3                 -0.511871            -0.400422            0.517257
# 4                 -0.504702            -0.422589           -0.226790
# ...                     ...                  ...                 ...
# 203763            -0.577099            -0.613614            0.241128
# 203764             0.162722             0.010822            1.461330
# 203765             1.261246             1.985050            1.461330
# 203766            -0.397749            -0.411776            1.461330
# 203767            -0.577099            -0.613614            0.241128
#
#         1.4613689382001922  0.01827940003744589  -0.0874901561101501  \
# 0                -0.978556             0.018279            -0.087490
# 1                -0.978556            -0.098889            -0.106715
# 2                 0.241406             1.072793             0.085530
# 3                 0.579382             0.018279             0.277775
# 4                -0.117629             0.018279             0.277775
# ...                    ...                  ...                  ...
# 203763            0.241406             0.018279            -0.087490
# 203764            1.461369            -0.098889            -0.087490
# 203765            1.461369             0.018279            -0.087490
# 203766            1.461369            -0.098889            -0.087490
# 203767            0.241406            -0.098889            -0.087490
#
#         -0.13115530389558736  -0.09752359377152515  -0.12061340670311574  \
# 0                  -0.131155             -0.097524             -0.120613
# 1                  -0.131155             -0.183671             -0.120613
# 2                  -0.131155              0.677799             -0.120613
# 3                   0.326394              1.293750              0.178136
# 4                   0.413931              1.149556             -0.696053
# ...                      ...                   ...                   ...
# 203763             -0.131155             -0.097524             -0.120613
# 203764             -0.084674             -0.140597             -1.760926
# 203765             -0.131155             -0.097524             -0.120613
# 203766             -0.084674             -0.140597              1.519700
# 203767             -0.084674             -0.140597              1.519700
#
#         -0.11979245961251665
# 0                  -0.119792
# 1                  -0.119792
# 2                  -0.119792
# 3                   0.179117
# 4                  -0.695540
# ...                      ...
# 203763             -0.119792
# 203764             -1.760984
# 203765             -0.119792
# 203766              1.521399
# 203767              1.521399
#
# [203768 rows x 167 columns]

# %%
# Pass unknown to number 3
classes.loc[classes['class'] == 'unknown', 'class'] = 3
print('Label 1 belongs to illicit transactions, label 2 to licit transactions and label 3 to unknown transactions.\n')
print('Shape of classes', classes.shape)
print('Shape of edges', classes.shape)
print('Shape of features', features.shape)
# Out:
# Label 1 belongs to illicit transactions, label 2 to licit transactions and label 3 to unknown transactions.
#
# Shape of classes (203769, 2)
# Shape of edges (203769, 2)
# Shape of features (203768, 167)

# %%
classes.groupby(['class']).count()
# Out:
#          txId
# class
# 3      157205
# 1        4545
# 2       42019

# %%
features.shape
classes.shape
# Out:
# (203769, 2)

# %%
# Merge the DataFrames on the column 'source', assuming it's the same name in both DataFrames
df_merged = pd.merge(features, classes, on='txId', how='left')
df_merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3780\1618387619.py in ?()
#       1 # Merge the DataFrames on the column 'source', assuming it's the same name in both DataFrames
# ----> 2 df_merged = pd.merge(features, classes, on='txId', how='left')
#       3 df_merged.head()
#
# c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'txId'

# %%
generate_graph = True
if generate_graph:
    # Create an empty graph
    G = nx.Graph()

    for _, row in df_merged.iterrows():
        # Extract node ID and attributes
        node_id = row['txId']
        node_attributes = row.drop('txId').to_dict()
        
        # Add node to the graph with its attributes
        G.add_node(node_id, **node_attributes)

    # Add edges to the graph
    for _, row in edges.iterrows():
        G.add_edge(row['txId1'], row['txId2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       2 if generate_graph:
#       3     # Create an empty graph
#       4     G = nx.Graph()
# ----> 6     for _, row in df_merged.iterrows():
#       7         # Extract node ID and attributes
#       8         node_id = row['txId']
#       9         node_attributes = row.drop('txId').to_dict()
#
# NameError: name 'df_merged' is not defined

# %%
def detect_communities(g, method):
    if isinstance(g, nx.DiGraph):
      g = nx.Graph(g)


    if method == 'girvan-newman':
      communities_generator = girvan_newman(g)
      print(communities_generator)
      communities = []
      for community in communities_generator:
        print(community)
        communities.append([list(c) for c in community])

      total_modularity = 0
      for i in range(len(communities)):
        modularity = nx.algorithms.community.modularity(g, communities[i])
        total_modularity += modularity

      total_modularity /= len(communities)
      return communities, total_modularity

    elif method == 'louvain':
      louvain = louvain.best_partition(g)
      communities = [[] for _ in range(max(louvain.values()) + 1)]
      for node, community_id in louvain.items():
          communities[community_id].append(node)

      modularity = nx.algorithms.community.modularity(g, communities)
      return communities, modularity

    else:
      print('Entered an invalid method')
      return None

# %%
communities_girvan, modularities = detect_communities(graph, method='girvan-newman')
# Out:
# <generator object girvan_newman at 0x000001E8D95255D0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 communities_girvan, modularities = detect_communities(graph, method='girvan-newman')
#
# Cell In[18], line 10, in detect_communities(g, method)
#       8 print(communities_generator)
#       9 communities = []
# ---> 10 for community in communities_generator:
#      11   print(community)
#      12   communities.append([list(c) for c in community])
#
# File c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\networkx\algorithms\community\centrality.py:147, in girvan_newman(G, most_valuable_edge)
#     145 g.remove_edges_from(nx.selfloop_edges(g))
#     146 while g.number_of_edges() > 0:
# --> 147     yield _without_most_central_edges(g, most_valuable_edge)
#
# File c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\networkx\algorithms\community\centrality.py:166, in _without_most_central_edges(G, most_valuable_edge)
#     164 num_new_components = original_num_components
#     165 while num_new_components <= original_num_components:
# --> 166     edge = most_valuable_edge(G)
#     167     G.remove_edge(*edge)
#     168     new_components = tuple(nx.connected_components(G))
#
# File c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\networkx\algorithms\community\centrality.py:138, in girvan_newman.<locals>.most_valuable_edge(G)
#     132 """Returns the edge with the highest betweenness centrality
#     133 in the graph `G`.
#     134
#     135 """
#     136 # We have guaranteed that the graph is non-empty, so this
#     137 # dictionary will never be empty.
# --> 138 betweenness = nx.edge_betweenness_centrality(G)
#     139 return max(betweenness, key=betweenness.get)
#
# File c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\networkx\classes\backends.py:148, in _dispatch.<locals>.wrapper(*args, **kwds)
#     144         else:
#     145             raise NetworkXNotImplemented(
#     146                 f"'{name}' not implemented by {plugin_name}"
#     147             )
# --> 148 return func(*args, **kwds)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 16:4, in argmap_edge_betweenness_centrality_13(G, k, normalized, weight, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\networkx\algorithms\centrality\betweenness.py:231, in edge_betweenness_centrality(G, k, normalized, weight, seed)
#     228 for s in nodes:
#     229     # single source shortest paths
#     230     if weight is None:  # use BFS
# --> 231         S, P, sigma, _ = _single_source_shortest_path_basic(G, s)
#     232     else:  # use Dijkstra's algorithm
#     233         S, P, sigma, _ = _single_source_dijkstra_path_basic(G, s, weight)
#
# File c:\Users\Usuario\anaconda3\envs\graph-anomaly-myenv\Lib\site-packages\networkx\algorithms\centrality\betweenness.py:259, in _single_source_shortest_path_basic(G, s)
#     257 sigma[s] = 1.0
#     258 D[s] = 0
# --> 259 Q = deque([s])
#     260 while Q:  # use BFS to find shortest paths
#     261     v = Q.popleft()
#
# KeyboardInterrupt:
